# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyDiallo/data-science-portfolio/blob/main/01-titanic/titanic_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titanic Survival Prediction
#
# ## Machine Learning Classification Project
#
# This project uses the Titanic dataset to analyze passenger survival
# and build machine learning models to predict survival.
#
# ### Project Goals
#
# - Explore the Titanic dataset
# - Clean and prepare the data
# - Analyze survival patterns
# - Create new features
# - Train machine learning models
# - Compare model performance
# - Identify important features
#
# ### Tools
#
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - KaggleHub
